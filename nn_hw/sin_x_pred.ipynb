# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def generate_training_sample():
    training_x = list(np.random.rand(100000) * 10)
    training_y = list(map(lambda x: math.sin(x), training_x))

    return training_x, training_y

# %%
def my_loss(y_pred, y_true):
    return y_pred - y_true

# %%
X, y = generate_training_sample()
print(X[0])
print(y[0])
X_train = X[:90000]
y_train = y[:90000]
X_valid = X[90000:]
y_valid = y[90000:]
# Out:
# 4.491868665409386
# -0.9757837690935649

# %%
model = keras.Sequential([
    layers.Dense(100, activation='tanh', input_shape=[1]),
    layers.Dense(100, activation='tanh'),
    layers.Dense(1, activation='sigmoid')
])
model.compile(
    optimizer="adam",
    loss="mae",
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=100,
    epochs=500
)
# Out:
# Train on 90000 samples, validate on 10000 samples
# Epoch 1/500
# 90000/90000 [==============================] - 1s 13us/sample - loss: 0.4868 - acc: 3.3333e-05 - val_loss: 0.4844 - val_acc: 0.0000e+00
# Epoch 2/500
# 90000/90000 [==============================] - 1s 12us/sample - loss: 0.4556 - acc: 4.4444e-05 - val_loss: 0.4323 - val_acc: 0.0000e+00
# Epoch 3/500
# 90000/90000 [==============================] - 1s 12us/sample - loss: 0.4223 - acc: 4.4444e-05 - val_loss: 0.4294 - val_acc: 0.0000e+00
# Epoch 4/500
# 90000/90000 [==============================] - 1s 12us/sample - loss: 0.4216 - acc: 4.4444e-05 - val_loss: 0.4288 - val_acc: 0.0000e+00
# Epoch 5/500
# 90000/90000 [==============================] - 1s 12us/sample - loss: 0.4213 - acc: 4.4444e-05 - val_loss: 0.4289 - val_acc: 0.0000e+00
# Epoch 6/500
# 90000/90000 [==============================] - 1s 12us/sample - loss: 0.4210 - acc: 4.4444e-05 - val_loss: 0.4286 - val_acc: 0.0000e+00
# Epoch 7/500
# ...

# %%
import pandas as pd

# convert the training history to a dataframe
history_df = pd.DataFrame(history.history)
# use Pandas native plot method
history_df['loss'].plot()
# Out:
# <AxesSubplot:>

# %%
test_x = [i for i in range(0, 10)]
test_y = [math.sin(i) for i in range(0, 10)]
predicted_y = model.predict([test_x])

# %%
plt.plot(test_x, test_y)
plt.plot(test_x, predicted_y)
plt.legend(['true', 'predicted'])
